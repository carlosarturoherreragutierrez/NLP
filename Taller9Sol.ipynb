# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguaje Natural
#
# ## Taller #9: Modelado de temas
# `Fecha de entrega: Mayo 6, 2021. (Antes del inicio de la próxima clase).`
#
# `Modo de entrega: Subir link de GitHub al aula virtual.`

# %%
import re
import pandas as pd 
from pprint import pprint

from nltk.corpus import stopwords
stopwords = stopwords.words('spanish')

import pyLDAvis.gensim_models
from gensim.models import LdaModel
from gensim.corpora import Dictionary

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
import random

# %%
# Cargar datos
path = 'C:/Bases_kl/reviews_vidjew_es.csv '
data = pd.read_csv(path)
data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category
# 0       es          jewelry
# 1       es      video_games
# 2       es      video_games
# 3       es      video_games
# 4       es      video_games

# %% [markdown]
# ###  `[12 pts]` Punto 1: Hacer pre-procesamiento del texto

# %%
def pre_procesado(texto):
    texto = texto.lower()
    texto = re.sub(r"[\W\d]+", " ", texto)
    texto = [palabra for palabra in texto.split() if palabra not in stopwords]
    return texto 

data['Pre-Processed'] = data['review_body'].apply(lambda texto: pre_procesado(texto))

data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category                                      Pre-Processed
# 0       es          jewelry        [buen, buena, calidad, buena, presentación]
# 1       es      video_games  [producto, perfecto, salir, casa, nintendo, sw...
# 2       es      video_games  [funciona, nintendo, switch, forma, emparejarl...
# 3       es      video_games  [recomendado, utilizo, pc, dan, ningún, proble...
# 4       es      video_games  [cable, funciona, bien, podria, ser, mas, larg...

# %% [markdown]
# ###  `[10 pts]` Punto 2: Modelo de LDA

# %%
random.seed(1234)
dictionary = Dictionary(data['Pre-Processed'].values)
dictionary.filter_extremes(no_below=5, no_above=0.5) 
corpus = [dictionary.doc2bow(text) for text in data['Pre-Processed'].values]
model = LdaModel(corpus = corpus, id2word = dictionary, num_topics = 5, passes=100)

# %% [markdown]
# ###  `[25 pts]` Punto 3: Visualización de LDA

# %%
lda_display = pyLDAvis.gensim_models.prepare(model, corpus, dictionary,sort_topics='True')
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1002020497015286249664535356"></div>
# <script type="text/javascript">
#
# var ldavis_el1002020497015286249664535356_data = {"mdsDat": {"x": [0.24172990323969556, -0.13831131400063937, 0.08495479600193637, -0.09049721824284573, -0.09787616699814662], "y": [0.017051499465938293, -0.15572303100361248, -0.06661434502251824, 0.01242568251014683, 0.19286019405004562], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [22.059168273305264, 21.634346264270448, 20.76075026905408, 17.80357321041163, 17.742161982958578]}, "tinfo": {"Term": ["juego", "calidad", "precio", "bonito", "mando", "bonitos", "d\u00eda", "solo", "plata", "buena", "llegado", "original", "producto", "jugar", "lleg\u00f3", "pulsera", "funciona", "queda", "colgante", "pedido", "puede", "grandes", "amazon", "mas", "foto", "vale", "pendientes", "si", "parece", "tal", "bonito", "bonitos", "plata", "colgante", "grandes", "fina", "regalar", "contenta", "pandora", "preciosa", "elegante", "encantada", "elegantes", "pulseras", "c\u00f3modos", "pesan", "preciosos", "realidad", "perdi\u00f3", "ven", "pendientes", "fea", "negra", "cuesta", "acero", "sistema", "quedan", "mujer", "queda", "pulsera", "tal", "peque\u00f1os", "color", "peque\u00f1a", "cadena", "foto", "encant\u00f3", "regalo", "tama\u00f1o", "ni\u00f1as", "bonita", "bien", "cierre", "dos", "demasiado", "grande", "bastante", "pl\u00e1stico", "peque\u00f1o", "parece", "calidad", "compra", "buena", "pedido", "gracias", "llegar", "entregado", "recibido", "meses", "dinero", "luego", "disco", "todav\u00eda", "esperando", "funcionar", "transporte", "alg\u00fan", "d\u00eda", "sony", "perdido", "compras", "muchas", "repartidor", "gente", "env\u00edo", "dice", "devoluci\u00f3n", "despu\u00e9s", "cosas", "mejores", "fecha", "dicen", "espero", "amazon", "devolver", "lleg\u00f3", "r\u00e1pido", "llegado", "nunca", "todas", "producto", "tiempo", "hacer", "caja", "ven\u00eda", "llego", "sido", "perfecto", "as\u00ed", "roto", "juego", "parte", "si", "bien", "mas", "q", "enseguida", "c\u00f3modo", "baja", "rompi\u00f3", "bonitas", "ajusta", "relaci\u00f3n", "acabados", "detalle", "juguete", "bajo", "excesivamente", "media", "tra\u00eda", "collar", "precio", "mala", "malo", "descripci\u00f3n", "general", "venia", "material", "encajan", "principio", "puse", "funci\u00f3n", "tienda", "calidad", "pueden", "igual", "buena", "bueno", "sonido", "puede", "parece", "pedir", "tan", "buen", "ser", "gustado", "mejor", "aunque", "bien", "juegos", "producto", "si", "mal", "tama\u00f1o", "bastante", "regalo", "mas", "perfecto", "lleg\u00f3", "vale", "correcto", "cargador", "contento", "bot\u00f3n", "volver\u00eda", "cierra", "brillo", "original", "envio", "imagen", "azul", "p\u00e9simo", "encima", "rapidez", "adapta", "instrucciones", "funda", "mando", "ped\u00ed", "resulta", "tacto", "primera", "mont\u00f3n", "ir", "respecto", "switch", "rompio", "junto", "llegaron", "solo", "barato", "deber\u00eda", "cumple", "momento", "mas", "vez", "comprar", "si", "pena", "nintendo", "vendedor", "llegado", "bien", "funciona", "compra", "producto", "esperaba", "buen", "mismo", "mejor", "precio", "espa\u00f1ol", "hijo", "versi\u00f3n", "excelente", "xbox", "pc", "historia", "castellano", "italiano", "presentaci\u00f3n", "jugando", "funcionan", "usb", "one", "divertido", "much\u00edsimo", "ruido", "cerrar", "ningun", "ingles", "familia", "mientras", "\u00fanica", "poder", "exactamente", "toda", "jugar", "unas", "play", "siendo", "juego", "trae", "funciona", "decir", "problema", "perfectamente", "mandos", "si", "viene", "puedo", "ps", "va", "bien", "hace", "perfecto", "puede", "aunque", "solo", "bastante", "gran", "recomendable", "mando", "caja"], "Freq": [118.0, 144.0, 116.0, 62.0, 53.0, 38.0, 48.0, 46.0, 34.0, 65.0, 50.0, 32.0, 105.0, 34.0, 43.0, 37.0, 35.0, 35.0, 24.0, 24.0, 50.0, 24.0, 34.0, 64.0, 51.0, 19.0, 28.0, 113.0, 48.0, 29.0, 61.994328014754444, 38.011275667307814, 33.394256660450175, 24.17186241636529, 23.245372580644336, 14.022045342198044, 14.018091001096266, 11.252579089580106, 8.48713015518334, 8.48690312655 ...

# %% [markdown]
# ###  `[3 pts]` Preguntas
#
# - ¿Qué conclusiones puede sacar de los resultados de los últimos tres talleres, usando diferentes modelos pero los mismos datos?

# %%
En los últimos dos modelos tengo la posibilidad de identificar los parametros con los cuales obtengo los mejores resultados con el modelo,
definir las categorias en las cuales puedo clasificar el contenido de los documentos e identificar los documentos más representativos en cada una de las clase
En los 3 modelos tengo la posibilidad de identificar las palabras más significativos para cada una de las clases.
